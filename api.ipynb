# %%
pip install google-api-python-client
# Out:
# ...
#   Using cached google_api_python_client-2.186.0-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached httplib2-0.31.0-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached google_auth-2.42.1-py2.py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached google_auth_httplib2-0.2.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached googleapis_common_protos-1.71.0-py3-none-any.whl.metadata (9.4 kB)
# ...
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# ...
# Using cached google_api_python_client-2.186.0-py3-none-any.whl (14.5 MB)
# Using cached google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Using cached google_auth-2.42.1-py2.py3-none-any.whl (222 kB)
# Using cached google_auth_httplib2-0.2.1-py3-none-any.whl (9.5 kB)
# Using cached httplib2-0.31.0-py3-none-any.whl (91 kB)
# ...

# %%
# Out:
# --------------------------------------------------------
# Comment By: @Jintuannam_muzik
# Comment Text: bản 1 tiếng cho bạn nào cần<br><a href="https://www.youtube.com/watch?v=fq0eCS7dRXs">https://youtu.be/fq0eCS7dRXs</a>
# Likes on Comment: 2
# Comment Date: 2025-10-30T18:56:08Z
# ...
#
# Comment By: @HBL-pr6nx
# <br>Là tại sao Anh làm gì có lỗikẻ tội rốig nên lờicũng thương em à
# Likes on Comment: 42
# Comment Date: 2025-10-28T04:00:22Z
# ...
#
# Comment By: @AnhVuMusicOfficial
# Comment Text: Bản phối hay quá 😢
# Likes on Comment: 5
# Comment Date: 2025-10-28T05:17:21Z
# ...
#
# Comment By: @NhiPhan-ln3gj
# Comment Text: Quá tuyệt vời giọng hát của bạn rất ngọt ngào lãng mạn nhẹ nhàng Nga v mình rất thích 👍👍🎤🎶💯🎼🎵🎶💖💖🌟
# Likes on Comment: 0
# Comment Date: 2025-11-01T07:15:31Z
# ...
#
# Comment By: @thienhoakim7314
# Comment Text: bài này châu khải phong hát thì tuyệt vời
# Likes on Comment: 2
# Comment Date: 2025-10-31T01:58:27Z
# ...
#
# Comment By: @kimvo5090
# Comment Text: Hay quá ❤
# Likes on Comment: 0
# ...
